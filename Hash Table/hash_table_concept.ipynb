# %% [markdown]
# ### 해시 테이블
#
# * 굉장히 강력한 자료구조인데, 언제, 어떻게 사용하는지가 더 중요합니다.

# %% [markdown]
# 두가지로 나뉩니다.
# 1. Array list 기반
# - 해시 테이블에서는 충돌이 일어납니다. 이 충돌을 막기 위한 방법으로 open addressing 방법이 있습니다.
# 2. Array list 와 linked list 기반
# - 충돌을 막는 방법 중 seperate chaining방법을 사용합니다.

# %% [markdown]
# ### 정의
# * 효율적인 탐색을 위한 자료구조로서 키 - 벨류로 pair가 된 데이터를 입력받습니다. 해시함수 h에 키값을 넣어 얻은 해시값h(k)를 위치로 지정합니다.
# * 시간복잡도 : 모두 O(1)

# %%
def hashFunction(key):
    return (key % 9)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hashFunction = {"key":"value"}

# %%
hashFunction[2024397] = "노정호"
hashFunction[2024399] = "배준석"
hashFunction[2024401] = "정재헌"
hashFunction[2024402] = "남영욱"

# %%
# 해시값으로 7이 나오면 노정호 저장

# %% [markdown]
# ### Direct-address table 개념

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### key 값이 인덱스가 되는 테이블입니다.
# 키값이 3 >> value값이 3
# (해시테이블보다 인자가 1개 없습니다.)

# %% [markdown]
# ##### 다이렉트 어드레스 테이블은 문제가 많습니다.
# > 1. 문자열로 들어오면 인덱스로 들어올수가 없습니다.
#
# > 2. 키값을 인덱스로 갖는 테이블을 만들면 앞에 있는 무수한 메모리가 낭비됩니다.

# %%
# 다이렉트 어드레스를 쓰지 말고 해시 테이블을 생각해내게 됩니다.
def hashFunction(key):
    return key / 2
# 이렇게 가공해요
# 문자열이 들어와도
return stringToInteger(key) 
# 이런걸 통해서 숫자로 바꿔요

# %% [markdown]
# - 단점
# 1. 데이터가 해당 인덱스에 이미 존재해서 충돌하는 경우
# * collision
# > 1. open addressing으로 해결합니다
#  ▶ 충돌날 경우 인덱스 아래로 한번 이동해요
#
# > 2. seperate chaining

# %% [markdown]
# #### 신경쓸 점은 시간복잡도
# - 충돌이 일어나더라도 충돌의 횟수를 줄여줍니다.
# 키값에 해당하는 인덱스값으로 O(1)의 시간복잡도로 이동해줘요
