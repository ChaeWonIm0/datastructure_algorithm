# %% [markdown]
# #### dictionary
#
# * 코딩테스트에서 매우 자주 쓰여요.
# * 내부 동작은 해시 테이블로 구현되요.
# * 문제에서 언제 써야하는지, 어떤 연산이 중요한지 아는것도 필요해요.

# %% [markdown]
# ![image.png](attachment:image.png)
# * 이 형태를 단순화 시킬 겁니다.

# %%
student = {"key":"value"}
student[2024397] = "노정호"
student[2024399] = "배준석"
student[2024401] = "정재헌"
student[2024402] = "남영욱"

# %%
student
# Out:
# {'key': 'value',
#  2024397: '노정호',
#  2024399: '배준석',
#  2024401: '정재헌',
#  2024402: '남영욱'}

# %% [markdown]
# #### 강력한 IN의 역할
# * if music in score2:
# *    pass
# 이 인덱스가 해시테이블에 존재하는지 안하는지 검색하는데, 시간이 O(1)밖에 걸리지 않습니다!
# > list로 할 경우 전부 순회를 해야 해서 시간복잡도 O(n)이 걸리게 됩니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
if 2022408 in student:
    pass

# %% [markdown]
# ##### 딕셔너리는 시간복잡도를 낮추기 위해 memory를 사용합니다!
# + in 연산자의 기능

# %%
score = [98,91,10]
